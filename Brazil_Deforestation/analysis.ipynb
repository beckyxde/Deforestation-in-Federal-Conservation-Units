# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
from os import path

df = pd.read_csv ('/Users/BeckyIngram/Downloads/deforestation_Brazil.csv')

# %%
df.sample(5)
# Out:
#                  Conservation Unity Name Protection group  Year of creation  \
# 224                      REBIO Bom Jesus  full protection              2012
# 238              REBIO do Atol das Rocas  full protection              1979
# 212                      PARNA Guaricana  full protection              2014
# 143                  FLONA Mapiá-Inauini  sustainable use              1989
# 45   ARIE Serra da Abelha e Rio da Prata  sustainable use              1996
#
#     estimated area of CU (ha)            Biome Have monitoring (PRODES)  \
# 224                    34,179  Atlantic forest                       No
# 238                    35,187   Marine - Coast                       No
# 212                    49,300  Atlantic forest                       No
# 143                   368,950           Amazon                      Yes
# 45                      5,017  Atlantic forest                       No
#
# ...

# %%
df.iloc[:, : 10]
# Out:
#                           Conservation Unity Name Protection group  \
# 0                                 APA Anhatomirim  sustainable use
# 1    APA Bacia Hidrográfica do Rio Paraíba do Sul  sustainable use
# 2                     APA Barra do Rio Mamanguape  sustainable use
# 3                       APA Carste da Lagoa Santa  sustainable use
# 4                         APA Cavernas do Peruaçu  sustainable use
# ..                                            ...              ...
# 322                                  REVIS de Una  full protection
# 323            REVIS do Arquipélago de Alcatrazes  full protection
# 324                       REVIS do Rio dos Frades  full protection
# 325                    REVIS dos Campos de Palmas  full protection
# 326                          REVIS Ilha dos Lobos  full protection
#
#      Year of creation estimated area of CU (ha)            Biome  \
# 0                1992                     4,437   Marine - Coast
# ...
